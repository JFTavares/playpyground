# %%
import time
import random 
import statistics

# %%
# CONSTANTS (weights in grams) 
GOAL = 50000
NUM_RATS = 50  # number of adult breeding rats in each generation
INITIAL_MIN_WT = 200
INITIAL_MAX_WT = 600
INITIAL_MODE_WT = 300
MUTATE_ODDS = 0.01
MUTATE_MIN = 0.5
MUTATE_MAX = 1.2
LITTER_SIZE = 8
LITTERS_PER_YEAR = 10
GENERATION_LIMIT = 500

# %%
if NUM_RATS % 2 != 0:
    NUM_RATS += 1

# %%
def populate(num_rats, min_wt, max_wt, mode_wt):
    """Initialize a population with a triangular distribution of weights."""
    return [int(random.triangular(min_wt, max_wt, mode_wt))\
            for i in range(num_rats)]

# %%
generations = 0

parents = populate(NUM_RATS, INITIAL_MIN_WT, INITIAL_MAX_WT, INITIAL_MODE_WT)
print("initial population weights = {}".format(parents))
# Out:
# initial population weights = [506, 296, 367, 450, 388, 289, 315, 274, 480, 500, 299, 476, 345, 357, 359, 402, 286, 265, 323, 372, 450, 502, 417, 262, 318, 428, 249, 445, 367, 418, 377, 272, 362, 274, 218, 380, 331, 348, 466, 533, 314, 313, 429, 269, 279, 366, 421, 455, 269, 301]

# %%
def fitness(population, goal):
    """Measure population fitness based on an attribute mean vs target."""
    ave = statistics.mean(population)
    return ave / goal

# %%
popl_fitness = fitness(parents, GOAL)
print("initial population fitness = {}".format(popl_fitness))
print("number to retain = {}".format(NUM_RATS))

ave_wt = []
# Out:
# initial population fitness = 0.007159199999999999
# number to retain = 50

# %%
def select(population, to_retain):
    """Cull a population to contain only a specified number of members."""
    sorted_population = sorted(population)
    to_retain_by_sex = to_retain//2
    members_per_sex = len(sorted_population)//2
    females = sorted_population[:members_per_sex]
    males = sorted_population[members_per_sex:]
    selected_females = females[-to_retain_by_sex:]
    selected_males = males[-to_retain_by_sex:]
    return selected_males, selected_females

# %%
def breed(males, females, litter_size):
    """Crossover genes among members of a population."""
    random.shuffle(males)
    random.shuffle(females)
    children = []
    for male, female in zip(males, females):
        for child in range(litter_size):
            child = random.randint(female, male)
            children.append(child)
    return children

# %%
def mutate(children, mutate_odds, mutate_min, mutate_max):
    """Randomly alter rat weights using input odds & fractional changes."""
    for index, rat in enumerate(children):
        if mutate_odds >= random.random():
            children[index] = round(rat * random.uniform(mutate_min,
                                                         mutate_max))
    return children

# %%
while popl_fitness < 1 and generations < GENERATION_LIMIT:
        selected_males, selected_females = select(parents, NUM_RATS)
        children = breed(selected_males, selected_females, LITTER_SIZE)
        children = mutate(children, MUTATE_ODDS, MUTATE_MIN, MUTATE_MAX)
        parents = selected_males + selected_females + children
        popl_fitness = fitness(parents, GOAL)
        print("Generation {} fitness = {:.4f}".format(generations,
                                                      popl_fitness))
        ave_wt.append(int(statistics.mean(parents)))
        generations += 1
# Out:
# Generation 0 fitness = 0.0071
# Generation 1 fitness = 0.0083
# Generation 2 fitness = 0.0089
# Generation 3 fitness = 0.0094
# Generation 4 fitness = 0.0098
# Generation 5 fitness = 0.0101
# Generation 6 fitness = 0.0103
# Generation 7 fitness = 0.0105
# Generation 8 fitness = 0.0107
# Generation 9 fitness = 0.0110
# Generation 10 fitness = 0.0114
# Generation 11 fitness = 0.0116
# Generation 12 fitness = 0.0118
# Generation 13 fitness = 0.0120
# Generation 14 fitness = 0.0121
# Generation 15 fitness = 0.0122
# Generation 16 fitness = 0.0122
# Generation 17 fitness = 0.0122
# Generation 18 fitness = 0.0123
# Generation 19 fitness = 0.0123
# Generation 20 fitness = 0.0123
# Generation 21 fitness = 0.0124
# Generation 22 fitness = 0.0128
# Generation 23 fitness = 0.0132
# Generation 24 fitness = 0.0135
# Generation 25 fitness = 0.0139
# Generation 26 fitness = 0.0143
# Generation 27 fitness = 0.0148
# Generation 28 fitness = 0.0151
# Generation 29 fitness = 0.0154
# Generation 30 fitness = 0.0158
# Generation 31 fitness = 0.0164
# Generation 32 fitness = 0.0170
# Generation 33 fitness = 0.0177
# Generation 34 fitness = 0.0183
# Generation 35 fitness = 0.0188
# Generation 36 fitness = 0.0192
# Generation 37 fitness = 0.0193
# Generation 38 fitness = 0.0196
# Generation 39 fitness = 0.0198
# Generation 40 fitness = 0.0201
# Generation 41 fitness = 0.0205
# Generation 42 fitness = 0.0211
# Generation 43 fitness = 0.0218
# Generation 44 fitness = 0.0225
# Generation 45 fitness = 0.0232
# Generation 46 fitness = 0.0239
# Generation 47 fitness = 0.0243
# Generation 48 fitness = 0.0246
# Generation 49 fitness = 0.0248
# Generation 50 fitness = 0.0250
# Generation 51 fitness = 0.0252
# Generation 52 fitness = 0.0258
# Generation 53 fitness = 0.0267
# Generation 54 fitness = 0.0274
# Generation 55 fitness = 0.0280
# Generation 56 fitness = 0.0285
# Generation 57 fitness = 0.0288
# Generation 58 fitness = 0.0293
# Generation 59 fitness = 0.0296
# Generation 60 fitness = 0.0300
# Generation 61 fitness = 0.0303
# Generation 62 fitness = 0.0304
# Generation 63 fitness = 0.0304
# Generation 64 fitness = 0.0306
# Generation 65 fitness = 0.0310
# Generation 66 fitness = 0.0322
# Generation 67 fitness = 0.0338
# Generation 68 fitness = 0.0355
# Generation 69 fitness = 0.0371
# Generation 70 fitness = 0.0382
# Generation 71 fitness = 0.0389
# Generation 72 fitness = 0.0394
# Generation 73 fitness = 0.0395
# Generation 74 fitness = 0.0400
# Generation 75 fitness = 0.0405
# Generation 76 fitness = 0.0419
# Generation 77 fitness = 0.0433
# Generation 78 fitness = 0.0444
# Generation 79 fitness = 0.0452
# Generation 80 fitness = 0.0458
# Generation 81 fitness = 0.0465
# Generation 82 fitness = 0.0474
# Generation 83 fitness = 0.0484
# Generation 84 fitness = 0.0498
# Generation 85 fitness = 0.0513
# Generation 86 fitness = 0.0523
# Generation 87 fitness = 0.0530
# Generation 88 fitness = 0.0537
# Generation 89 fitness = 0.0555
# Generation 90 fitness = 0.0572
# Generation 91 fitness = 0.0589
# Generation 92 fitness = 0.0600
# Generation 93 fitness = 0.0611
# Generation 94 fitness = 0.0615
# Generation 95 fitness = 0.0627
# Generation 96 fitness = 0.0645
# Generation 97 fitness = 0.0659
# Generation 98 fitness = 0.0672
# Generation 99 fitness = 0.0679
# Generation 100 fitness = 0.0688
# Generation 101 fitness = 0.0693
# Generation 102 fitness = 0.0697
# Generation 103 fitness = 0.0700
# Generation 104 fitness = 0.0711
# Generation 105 fitness = 0.0730
# Generation 106 fitness = 0.0752
# Generation 107 fitness = 0.0779
# Generation 108 fitness = 0.0799
# Generation 109 fitness = 0.0819
# Generation 110 fitness = 0.0833
# Generation 111 fitness = 0.0855
# Generation 112 fitness = 0.0877
# Generation 113 fitness = 0.0899
# Generation 114 fitness = 0.0927
# Generation 115 fitness = 0.0948
# Generation 116 fitness = 0.0964
# Generation 117 fitness = 0.0998
# Generation 118 fitness = 0.1032
# Generation 119 fitness = 0.1067
# Generation 120 fitness = 0.1102
# Generation 121 fitness = 0.1133
# Generation 122 fitness = 0.1162
# Generation 123 fitness = 0.1191
# Generation 124 fitness = 0.1214
# Generation 125 fitness = 0.1243
# Generation 126 fitness = 0.1263
# Generation 127 fitness = 0.1278
# Generation 128 fitness = 0.1284
# Generation 129 fitness = 0.1289
# Generation 130 fitness = 0.1292
# Generation 131 fitness = 0.1301
# Generation 132 fitness = 0.1317
# Generation 133 fitness = 0.1359
# Generation 134 fitness = 0.1418
# Generation 135 fitness = 0.1457
# Generation 136 fitness = 0.1497
# Generation 137 fitness = 0.1525
# Generation 138 fitness = 0.1551
# Generation 139 fitness = 0.1570
# Generation 140 fitness = 0.1612
# Generation 141 fitness = 0.1646
# Generation 142 fitness = 0.1677
# Generation 143 fitness = 0.1704
# Generation 144 fitness = 0.1752
# Generation 145 fitness = 0.1808
# Generation 146 fitness = 0.1843
# Generation 147 fitness = 0.1870
# Generation 148 fitness = 0.1885
# Generation 149 fitness = 0.1933
# Generation 150 fitness = 0.2010
# Generation 151 fitness = 0.2075
# Generation 152 fitness = 0.2129
# Generation 153 fitness = 0.2174
# Generation 154 fitness = 0.2207
# Generation 155 fitness = 0.2234
# Generation 156 fitness = 0.2255
# Generation 157 fitness = 0.2279
# Generation 158 fitness = 0.2311
# Generation 159 fitness = 0.2342
# Generation 160 fitness = 0.2366
# Generation 161 fitness = 0.2389
# Generation 162 fitness = 0.2437
# Generation 163 fitness = 0.2550
# Generation 164 fitness = 0.2635
# Generation 165 fitness = 0.2688
# Generation 166 fitness = 0.2737
# Generation 167 fitness = 0.2774
# Generation 168 fitness = 0.2818
# Generation 169 fitness = 0.2859
# Generation 170 fitness = 0.2890
# Generation 171 fitness = 0.2942
# Generation 172 fitness = 0.3018
# Generation 173 fitness = 0.3097
# Generation 174 fitness = 0.3148
# Generation 175 fitness = 0.3208
# Generation 176 fitness = 0.3278
# Generation 177 fitness = 0.3428
# Generation 178 fitness = 0.3582
# Generation 179 fitness = 0.3704
# Generation 180 fitness = 0.3804
# Generation 181 fitness = 0.3909
# Generation 182 fitness = 0.4020
# Generation 183 fitness = 0.4092
# Generation 184 fitness = 0.4142
# Generation 185 fitness = 0.4204
# Generation 186 fitness = 0.4341
# Generation 187 fitness = 0.4519
# Generation 188 fitness = 0.4669
# Generation 189 fitness = 0.4780
# Generation 190 fitness = 0.4867
# Generation 191 fitness = 0.4918
# Generation 192 fitness = 0.4969
# Generation 193 fitness = 0.5084
# Generation 194 fitness = 0.5209
# Generation 195 fitness = 0.5279
# Generation 196 fitness = 0.5345
# Generation 197 fitness = 0.5418
# Generation 198 fitness = 0.5463
# Generation 199 fitness = 0.5504
# Generation 200 fitness = 0.5542
# Generation 201 fitness = 0.5583
# Generation 202 fitness = 0.5637
# Generation 203 fitness = 0.5659
# Generation 204 fitness = 0.5690
# Generation 205 fitness = 0.5713
# Generation 206 fitness = 0.5785
# Generation 207 fitness = 0.5930
# Generation 208 fitness = 0.6107
# Generation 209 fitness = 0.6253
# Generation 210 fitness = 0.6362
# Generation 211 fitness = 0.6543
# Generation 212 fitness = 0.6668
# Generation 213 fitness = 0.6797
# Generation 214 fitness = 0.6907
# Generation 215 fitness = 0.7082
# Generation 216 fitness = 0.7341
# Generation 217 fitness = 0.7582
# Generation 218 fitness = 0.7772
# Generation 219 fitness = 0.7952
# Generation 220 fitness = 0.8137
# Generation 221 fitness = 0.8292
# Generation 222 fitness = 0.8403
# Generation 223 fitness = 0.8532
# Generation 224 fitness = 0.8738
# Generation 225 fitness = 0.8925
# Generation 226 fitness = 0.9084
# Generation 227 fitness = 0.9200
# Generation 228 fitness = 0.9335
# Generation 229 fitness = 0.9502
# Generation 230 fitness = 0.9646
# Generation 231 fitness = 0.9750
# Generation 232 fitness = 0.9988
# Generation 233 fitness = 1.0408

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2cd27e0bea29> in <module>
# ----> 1 print(males)
#
# NameError: name 'males' is not defined
